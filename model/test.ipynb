# %%
# After kernel restart - Fresh test
from LSTM_translator import load_translator_for_inference

translator_loaded = load_translator_for_inference('lstm_translator')

# Si il faut tu remplace test_tokens par:
# test_tokens = text.split(" ")

test_tokens = ['new', 'jersey', 'est', 'parfois', 'calme']
result = translator_loaded.translate_tokens(test_tokens)
print(result)
# Out:
# Loading model from lstm_translator...
# Model PreLoaded Successfully!
# Translator instance created.
# Vocabularies loaded.
# Rebuilding model architecture...
# Building the model with attention=True, bidirectional=True...
# 2025-09-29 15:41:59.015488: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-09-29 15:41:59.015510: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 48.00 GB
# 2025-09-29 15:41:59.015514: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 18.72 GB
# 2025-09-29 15:41:59.015533: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
git fetch origin

git checkout branch_to branch_from -- lstm_translator_data.pkl lstm_translator_main.h5 config.py LSTM_translator.py

# %%
git checkout origin/text_checks -- lstm_translator_main.h5 config.py LSTM_translator.py
